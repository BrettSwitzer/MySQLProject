# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posting_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(10)
# Out:
#                   job_title_short  \
# 406083             Cloud Engineer
# 355476              Data Engineer
# 33745                Data Analyst
# 243297               Data Analyst
# 675357  Machine Learning Engineer
# 30433                Data Analyst
# 358366           Business Analyst
# 733447               Data Analyst
# 192080               Data Analyst
# 46353           Software Engineer
#
#                                                 job_title  \
# 406083                         IT Infrastructure Engineer
# 355476                        Middle Python Data Engineer
# 33745                   Finance Analyst Project Analytics
# 243297                        Statistician / Data Analyst
# 675357                                        CVM Analyst
# 30433                                     HR Data Analyst
# 358366                         Business Analytics Manager
# 733447                                       Data Analyst
# 192080  Remote Jobs - Online Data Analyst (Dutch speaker)
# 46353                Lead Software Engineer, Localization
#
#                             job_location             job_via  \
# 406083                          Anywhere        via LinkedIn
# 355476     Sofia, Bulgaria   (+3 others)        via The Muse
# 33745        Hyderabad, Telangana, India        via LinkedIn
# 243297                      Thika, Kenya  via BrighterMonday
# 675357                          Anywhere        via LinkedIn
# 30433                         Boston, MA       via WJTV Jobs
# 358366                    Gdańsk, Poland           via BeBee
# 733447                             Spain     via Ai-Jobs.net
# 192080                          Anywhere        via LinkedIn
# 46353   San Vicente, Antioquia, Colombia           via BeBee
#
#        job_schedule_type  job_work_from_home          search_location  \
# 406083         Full-time                True              Netherlands
# 355476         Full-time               False                 Bulgaria
# 33745          Full-time               False                    India
# 243297         Full-time               False                    Kenya
# 675357         Full-time                True             South Africa
# 30433          Full-time               False  New York, United States
# 358366         Full-time               False                   Poland
# 733447         Full-time               False                    Spain
# 192080         Part-time                True              Netherlands
# 46353          Full-time               False                 Colombia
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 406083  2023-09-05 16:48:54                   True                 False
# 355476  2023-06-20 23:26:07                   True                 False
# 33745   2023-03-15 13:11:53                  False                 False
# 243297  2023-07-14 07:21:47                  False                 False
# 675357  2023-06-04 11:14:03                  False                 False
# 30433   2023-01-14 13:00:35                  False                  True
# 358366  2023-07-27 23:40:45                  False                 False
# 733447  2023-07-07 21:25:47                  False                 False
# 192080  2023-06-13 15:14:49                   True                 False
# 46353   2023-12-08 06:31:54                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 406083    Netherlands        None              NaN              NaN
# 355476       Bulgaria        None              NaN              NaN
# 33745           India        None              NaN              NaN
# 243297          Kenya        None              NaN              NaN
# 675357   South Africa        None              NaN              NaN
# 30433   United States        None              NaN              NaN
# 358366         Poland        None              NaN              NaN
# 733447          Spain        year         105000.0              NaN
# 192080    Netherlands        None              NaN              NaN
# 46353        Colombia        None              NaN              NaN
#
#                                   company_name  \
# 406083     Data Management Professionals (DMP)
# 355476                                  Exadel
# 33745                           Signant Health
# 243297                   Trans-Dimension Cyber
# 675357                   RecruitU South Africa
# 30433   Berkshire Hathaway Specialty Insurance
# 358366                                 Avantor
# 733447                          Octopus Energy
# 192080   TELUS International AI Data Solutions
# 46353                                 West CAP
#
#                                                job_skills  \
# 406083  ['sql', 'sql server', 'vmware', 'linux', 'wind...
# 355476  ['python', 'sql', 'docker', 'kubernetes', 'git...
# 33745                                           ['excel']
# 243297                            ['r', 'python', 'spss']
# 675357                             ['sql', 'python', 'r']
# 30433             ['sql', 'excel', 'power bi', 'tableau']
# 358366                                    ['go', 'excel']
# 733447     ['python', 'pandas', 'jupyter', 'spreadsheet']
# 192080                                             ['go']
# 46353                                             ['aws']
#
#                                           job_type_skills    job_posting_date
# 406083  {'cloud': ['vmware'], 'databases': ['sql serve... 2023-09-05 16:48:54
# 355476  {'async': ['jira', 'confluence'], 'other': ['d... 2023-06-20 23:26:07
# 33745                        {'analyst_tools': ['excel']} 2023-03-15 13:11:53
# 243297  {'analyst_tools': ['spss'], 'programming': ['r... 2023-07-14 07:21:47
# 675357            {'programming': ['sql', 'python', 'r']} 2023-06-04 11:14:03
# 30433   {'analyst_tools': ['excel', 'power bi', 'table... 2023-01-14 13:00:35
# 358366  {'analyst_tools': ['excel'], 'programming': ['... 2023-07-27 23:40:45
# 733447  {'analyst_tools': ['spreadsheet'], 'libraries'... 2023-07-07 21:25:47
# 192080                            {'programming': ['go']} 2023-06-13 15:14:49
# 46353                                  {'cloud': ['aws']} 2023-12-08 06:31:54

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original

df_altered
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785736   Pekerjaan tetap               False             Singapore
# 785737   Pekerjaan tetap               False               Germany
# 785738   Pekerjaan tetap               False              Malaysia
# 785739   Pekerjaan tetap               False                 Sudan
# 785740   Pekerjaan tetap               False                 India
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0       2023-06-16 13:44:15                  False                 False
# 1       2023-01-14 13:18:07                  False                 False
# 2       2023-10-10 13:14:55                  False                 False
# 3       2023-07-04 13:01:41                   True                 False
# 4       2023-08-07 14:29:36                  False                 False
# ...                     ...                    ...                   ...
# 785736  2023-03-13 06:16:16                  False                 False
# 785737  2023-03-12 06:18:18                  False                 False
# 785738  2023-03-12 06:32:36                  False                 False
# 785739  2023-03-12 06:32:15                  False                 False
# 785740  2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States        None              NaN              NaN
# 1              Mexico        None              NaN              NaN
# 2             Germany        None              NaN              NaN
# 3       United States        None              NaN              NaN
# 4               Sudan        None              NaN              NaN
# ...               ...         ...              ...              ...
# 785736      Singapore        None              NaN              NaN
# 785737        Germany        None              NaN              NaN
# 785738       Malaysia        None              NaN              NaN
# 785739          Sudan        None              NaN              NaN
# 785740          India        None              NaN              NaN
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 0                                                    None
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 0                                                    None
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                   ...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}
#
# [785741 rows x 17 columns]
