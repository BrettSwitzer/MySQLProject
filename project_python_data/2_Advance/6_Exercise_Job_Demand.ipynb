# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posting_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_cad['job_posted_date'] = pd.to_datetime(df_cad['job_posted_date'])

# %%
df['job_posting_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_cad = df[df['job_country'] == 'Canada'].copy()

# %%
print(df_cad['job_posted_date'].dtype)
# Out:
# object

# %%
df_cad
# Out:
#                   job_title_short  \
# 50      Machine Learning Engineer
# 59                  Data Engineer
# 81                   Data Analyst
# 85      Machine Learning Engineer
# 98           Senior Data Engineer
# ...                           ...
# 785317              Data Engineer
# 785327              Data Engineer
# 785339              Data Engineer
# 785511              Data Engineer
# 785643             Data Scientist
#
#                                                 job_title  \
# 50               Sr ML Engineer - Research & NLP (Remote)
# 59                   Data Engineer with Dremio Experience
# 81                                  Business Data Analyst
# 85      Machine Learning Engineer/Scientist High Perfo...
# 98                             Senior Data Engineer (AWS)
# ...                                                   ...
# 785317                        Data Engineer, Finance Data
# 785327                                Azure Data Engineer
# ...

# %%
df_cad['job_posted_month'] = df_cad['job_posted_date'].dt.strftime('%B')

df_cad
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 df_cad['job_posted_month'] = df_cad['job_posted_date'].dt.strftime('%B')
#       3 df_cad
#
# File c:\Users\Brett\Anaconda3\envs\python_course\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File c:\Users\Brett\Anaconda3\envs\python_course\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
print(df_cad['job_posted_date'].dtype)
# Out:
# object

# %%
df_cad_pivot = df_cad.pivot_table(index='job_posted_month', columns='job_title_short', aggfunc='size')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 df_cad_pivot = df_cad.pivot_table(index='job_posted_month', columns='job_title_short', aggfunc='size')
#
# File c:\Users\Brett\Anaconda3\envs\python_course\Lib\site-packages\pandas\core\frame.py:9509, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9492 @Substitution("")
#    9493 @Appender(_shared_docs["pivot_table"])
#    9494 def pivot_table(
#    (...)
#    9505     sort: bool = True,
#    9506 ) -> DataFrame:
#    9507     from pandas.core.reshape.pivot import pivot_table
# -> 9509     return pivot_table(
#    9510         self,
#    9511         values=values,
#    9512         index=index,
#    9513         columns=columns,
#    9514         aggfunc=aggfunc,
#    9515         fill_value=fill_value,
# ...

# %%
df_cad_pivot.reset_index(drop=True, inplace=True)
df_cad_pivot['month_no'] = pd.to_datetime(df_cad_pivot['job_posted_month'], format='%B').dt.month

df_cad_pivot.sort_values('month_no', inplace = True)
df_cad_pivot.set_index('job_posted_month', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Brett\Anaconda3\envs\python_course\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'job_posted_month'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 2
# ...
