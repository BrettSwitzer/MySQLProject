# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posting_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(5)
# Out:
#        job_title_short                          job_title  \
# 453015   Data Engineer        Data Engineer/ETL Developer
# 552212  Data Scientist                    Data Specialist
# 350487  Data Scientist                     Data Scientist
# 86455     Data Analyst  Analyst-Data Science Intermediate
# 230376   Data Engineer                      Data Engineer
#
#                         job_location               job_via job_schedule_type  \
# 453015                 Arlington, TX       via Trabajo.org         Full-time
# 552212                   Crowley, TX             via BeBee         Full-time
# 350487  Dubai - United Arab Emirates    via Learn4Good.com         Full-time
# 86455               Indianapolis, IN          via LinkedIn         Full-time
# 230376            Jakarta, Indonesia  via Jobs Trabajo.org         Full-time
#
#         job_work_from_home          search_location      job_posted_date  \
# 453015               False                  Georgia  2023-11-12 14:50:09
# 552212               False     Texas, United States  2023-11-28 19:01:25
# 350487               False     United Arab Emirates  2023-08-01 00:13:07
# 86455                False  Illinois, United States  2023-04-28 00:02:04
# 230376               False                Indonesia  2023-12-14 07:20:53
#
#         job_no_degree_mention  job_health_insurance           job_country  \
# 453015                  False                  True         United States
# 552212                   True                 False         United States
# 350487                  False                 False  United Arab Emirates
# 86455                   False                  True         United States
# 230376                  False                 False             Indonesia
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 453015        None              NaN              NaN
# 552212        None              NaN              NaN
# 350487        None              NaN              NaN
# 86455         None              NaN              NaN
# 230376        None              NaN              NaN
#
#                         company_name  \
# 453015                    Guidehouse
# 552212               Arthur Lawrence
# 350487                      Group 42
# 86455      Indiana University Health
# 230376  PT. Prima Fajar Cahaya Surya
#
#                                                job_skills  \
# 453015  ['sql', 'python', 'nosql', 'azure', 'databrick...
# 552212                                    ['sql', 'jira']
# 350487                                               None
# 86455   ['sql', 'sql server', 'power bi', 'tableau', '...
# 230376  ['r', 'python', 'sql', 'postgresql', 'oracle',...
#
#                                           job_type_skills    job_posting_date
# 453015  {'cloud': ['azure', 'databricks'], 'other': ['... 2023-11-12 14:50:09
# 552212        {'async': ['jira'], 'programming': ['sql']} 2023-11-28 19:01:25
# 350487                                               None 2023-08-01 00:13:07
# 86455   {'analyst_tools': ['power bi', 'tableau', 'ssr... 2023-04-28 00:02:04
# 230376  {'cloud': ['oracle'], 'databases': ['postgresq... 2023-12-14 07:20:53

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)
