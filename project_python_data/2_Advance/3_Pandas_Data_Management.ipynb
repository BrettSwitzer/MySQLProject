# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posting_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(10)
# Out:
#              job_title_short                             job_title  \
# 478723      Business Analyst          BI Analyst - Marketing focus
# 655239   Senior Data Analyst           Senior Data/Web Analyst H/F
# 528006  Senior Data Engineer        Senior Data Engineer I, Careem
# 774740          Data Analyst                          Data Analyst
# 351730     Software Engineer   Senior Software Engineer (Frontend)
# 539415          Data Analyst            Sales Support/Data Analyst
# 773878        Data Scientist              Traineeship Data science
# 565763         Data Engineer                   VP Data Engineering
# 475645          Data Analyst                Data Analyst Part Time
# 408801          Data Analyst  IT Data Analyst - Full time (Remote)
#
#               job_location                                            job_via  \
# 478723               Malta                                     via JobsFactor
# 655239       Paris, France                                          via BeBee
# 528006            Pakistan                             via Qureos Career Site
# 774740         Atlanta, GA                                      via SonicJobs
# 351730     Vienna, Austria                                    via Recruit.net
# 539415        Coventry, RI                                       via LinkedIn
# 773878  Delft, Netherlands                                          via BeBee
# 565763         England, UK                                          via BeBee
# 475645              Canada                                   via BeBee Canada
# 408801     Los Angeles, CA  via HR Software For Growing Businesses | Fresh...
#
#        job_schedule_type  job_work_from_home            search_location  \
# 478723         Full-time               False                      Malta
# 655239         Full-time               False                     France
# 528006         Full-time               False                   Pakistan
# 774740         Full-time               False                    Georgia
# 351730         Full-time               False                    Austria
# 539415         Full-time               False    New York, United States
# 773878         Full-time               False                Netherlands
# 565763         Full-time               False             United Kingdom
# 475645         Part-time               False                     Canada
# 408801         Full-time               False  California, United States
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 478723  2023-04-18 15:09:31                   True                 False
# 655239  2023-05-07 10:46:28                  False                 False
# 528006  2023-03-30 11:22:15                   True                 False
# 774740  2023-02-01 02:32:20                  False                 False
# 351730  2023-02-03 23:52:57                   True                 False
# 539415  2023-07-07 19:01:05                   True                  True
# 773878  2023-07-27 01:55:55                  False                 False
# 565763  2023-10-06 04:10:44                  False                 False
# 475645  2023-12-19 14:43:04                   True                 False
# 408801  2023-03-07 16:02:19                  False                 False
#
#            job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 478723           Malta        None              NaN              NaN
# 655239          France        None              NaN              NaN
# 528006        Pakistan        None              NaN              NaN
# 774740   United States        None              NaN              NaN
# 351730         Austria        None              NaN              NaN
# 539415   United States        None              NaN              NaN
# 773878     Netherlands        None              NaN              NaN
# 565763  United Kingdom        None              NaN              NaN
# 475645          Canada        None              NaN              NaN
# 408801   United States        None              NaN              NaN
#
#                 company_name  \
# 478723    Spoton Connections
# 655239            TechByTech
# 528006                Qureos
# 774740    Rose International
# 351730            Insideview
# 539415           Robert Half
# 773878         House of Bèta
# 565763  MARKJAMES SEARCH LTD
# 475645        Vox Media, LLC
# 408801              Hireably
#
#                                                job_skills  \
# 478723                            ['sql', 'r', 'tableau']
# 655239                 ['javascript', 'excel', 'tableau']
# 528006                                               None
# 774740  ['sas', 'sas', 'r', 'python', 'snowflake', 'un...
# 351730                                               None
# 539415                                     ['go', 'flow']
# 773878                            ['sql', 'vba', 'excel']
# 565763  ['sql', 'python', 'java', 'scala', 'aws', 'gcp...
# 475645      ['sql', 'r', 'python', 'tableau', 'power bi']
# 408801                                    ['java', 'c++']
#
#                                           job_type_skills    job_posting_date
# 478723  {'analyst_tools': ['tableau'], 'programming': ... 2023-04-18 15:09:31
# 655239  {'analyst_tools': ['excel', 'tableau'], 'progr... 2023-05-07 10:46:28
# 528006                                               None 2023-03-30 11:22:15
# 774740  {'analyst_tools': ['sas'], 'cloud': ['snowflak... 2023-02-01 02:32:20
# 351730                                               None 2023-02-03 23:52:57
# 539415         {'other': ['flow'], 'programming': ['go']} 2023-07-07 19:01:05
# 773878  {'analyst_tools': ['excel'], 'programming': ['... 2023-07-27 01:55:55
# 565763  {'cloud': ['aws', 'gcp'], 'libraries': ['hadoo... 2023-10-06 04:10:44
# 475645  {'analyst_tools': ['tableau', 'power bi'], 'pr... 2023-12-19 14:43:04
# 408801                   {'programming': ['java', 'c++']} 2023-03-07 16:02:19

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original

df_altered
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# 785740                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 0                             Watertown, CT            via Work Nearby
# 1              Guadalajara, Jalisco, Mexico           via BeBee México
# 2                           Berlin, Germany               via LinkedIn
# 3                           San Antonio, TX          via Diversity.com
# 4                            Washington, DC         via Clearance Jobs
# ...                                     ...                        ...
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785736   Pekerjaan tetap               False             Singapore
# 785737   Pekerjaan tetap               False               Germany
# 785738   Pekerjaan tetap               False              Malaysia
# 785739   Pekerjaan tetap               False                 Sudan
# 785740   Pekerjaan tetap               False                 India
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0       2023-06-16 13:44:15                  False                 False
# 1       2023-01-14 13:18:07                  False                 False
# 2       2023-10-10 13:14:55                  False                 False
# 3       2023-07-04 13:01:41                   True                 False
# 4       2023-08-07 14:29:36                  False                 False
# ...                     ...                    ...                   ...
# 785736  2023-03-13 06:16:16                  False                 False
# 785737  2023-03-12 06:18:18                  False                 False
# 785738  2023-03-12 06:32:36                  False                 False
# 785739  2023-03-12 06:32:15                  False                 False
# 785740  2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States        None              NaN              NaN
# 1              Mexico        None              NaN              NaN
# 2             Germany        None              NaN              NaN
# 3       United States        None              NaN              NaN
# 4               Sudan        None              NaN              NaN
# ...               ...         ...              ...              ...
# 785736      Singapore        None              NaN              NaN
# 785737        Germany        None              NaN              NaN
# 785738       Malaysia        None              NaN              NaN
# 785739          Sudan        None              NaN              NaN
# 785740          India        None              NaN              NaN
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 0                                                    None
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 0                                                    None
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                   ...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}
#
# [785741 rows x 17 columns]
